# %% [markdown]
# # W266 Authorship Attribution -- Data Retrieval

# %% [markdown]
# ## Import Libraries and Set up dependencies

# %%
import numpy as np 
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Clone Repo

# %%
# !git clone https://github.com/c-w/Gutenberg.git
# Out:
# fatal: destination path 'Gutenberg' already exists and is not an empty directory.

# %% [markdown]
# ### Install BDS-DB3

# %%
#don't use (Windows installation of bsddb3)
#!pip install bsddb3‑6.2.9‑pp37‑pypy37_pp73‑win_amd64.whl
#!pip install .

# %%
#linux installation of bsddb3
# !sudo apt-get install libdb++-dev
# !export BERKELEYDB_DIR=/usr
# !pip install .
# !sudo apt autoremove
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libdb++-dev is already the newest version (1:5.3.21~exp1ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %% [markdown]
# ### Install Dependencies

# %%
cd Gutenberg/
# Out:
# /content/Gutenberg

# %%
# !pip install virtualenv
# !virtualenv --no-site-packages virtualenv
# !. virtualenv/bin/activate
# !pip install -r requirements-dev.pip
# !pip install .
# Out:
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.7/dist-packages (20.13.4)
# Requirement already satisfied: distlib<1,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (0.3.4)
# Requirement already satisfied: filelock<4,>=3.2 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (3.6.0)
# Requirement already satisfied: six<2,>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (1.15.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (4.2.0)
# Requirement already satisfied: platformdirs<3,>=2 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (2.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->virtualenv) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->virtualenv) (3.10.0.2)
# usage: virtualenv [--version] [--with-traceback] [-v | -q] [--read-only-app-data] [--app-data APP_DATA] [--reset-app-data] [--upgrade-embed-wheels] [--discovery {builtin}] [-p py] [--try-first-with py_exe]
#                   [--creator {builtin,cpython3-posix,venv}] [--seeder {app-data,pip}] [--no-seed] [--activators comma_sep_list] [--clear] [--no-vcs-ignore] [--system-site-packages] [--symlinks | --copies] [--no-download | --download]
#                   [--extra-search-dir d [d ...]] [--pip version] [--setuptools version] [--wheel version] [--no-pip] [--no-setuptools] [--no-wheel] [--no-periodic-update] [--symlink-app-data] [--prompt prompt] [-h]
#                   dest
# virtualenv: error: unrecognized arguments: --no-site-packages
# SystemExit: 2
# /bin/bash: virtualenv/bin/activate: No such file or directory
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from -r requirements-dev.pip (line 1)) (6.3.2)
# Requirement already satisfied: flake8 in /usr/local/lib/python3.7/dist-packages (from -r requirements-dev.pip (line 2)) (4.0.1)
# Requirement already satisfied: nose2 in /usr/local/lib/python3.7/dist-packages (from -r requirements-dev.pip (line 3)) (0.11.0)
# Requirement already satisfied: responses in /usr/local/lib/python3.7/dist-packages (from -r requirements-dev.pip (line 4)) (0.20.0)
# Requirement already satisfied: importlib-metadata<4.3 in /usr/local/lib/python3.7/dist-packages (from flake8->-r requirements-dev.pip (line 2)) (4.2.0)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from flake8->-r requirements-dev.pip (line 2)) (2.8.0)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from flake8->-r requirements-dev.pip (line 2)) (2.4.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from flake8->-r requirements-dev.pip (line 2)) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<4.3->flake8->-r requirements-dev.pip (line 2)) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<4.3->flake8->-r requirements-dev.pip (line 2)) (3.10.0.2)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from nose2->-r requirements-dev.pip (line 3)) (1.15.0)
# Requirement already satisfied: urllib3>=1.25.10 in /usr/local/lib/python3.7/dist-packages (from responses->-r requirements-dev.pip (line 4)) (1.25.11)
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from responses->-r requirements-dev.pip (line 4)) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.0->responses->-r requirements-dev.pip (line 4)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.0->responses->-r requirements-dev.pip (line 4)) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.0->responses->-r requirements-dev.pip (line 4)) (2.10)
# Processing /content/Gutenberg
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: SPARQLWrapper>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from Gutenberg==0.8.2) (1.8.5)
# Requirement already satisfied: bsddb3>=6.1.0 in /usr/local/lib/python3.7/dist-packages (from Gutenberg==0.8.2) (6.2.9)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from Gutenberg==0.8.2) (0.16.0)
# Requirement already satisfied: pyparsing<3.0.0 in /usr/local/lib/python3.7/dist-packages (from Gutenberg==0.8.2) (2.4.7)
# Requirement already satisfied: rdflib-sqlalchemy>=0.3.8 in /usr/local/lib/python3.7/dist-packages (from Gutenberg==0.8.2) (0.5.0)
# Requirement already satisfied: rdflib<5.0.0,>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from Gutenberg==0.8.2) (4.2.2)
# Requirement already satisfied: requests>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from Gutenberg==0.8.2) (2.23.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from Gutenberg==0.8.2) (57.4.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib<5.0.0,>=4.2.0->Gutenberg==0.8.2) (0.6.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (1.15.0)
# Requirement already satisfied: alembic>=0.8.8 in /usr/local/lib/python3.7/dist-packages (from rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (1.7.7)
# Requirement already satisfied: SQLAlchemy>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (1.4.32)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (4.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (5.4.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (1.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.1->Gutenberg==0.8.2) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.1->Gutenberg==0.8.2) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.1->Gutenberg==0.8.2) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.5.1->Gutenberg==0.8.2) (2021.10.8)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.1.4->rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (1.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (3.10.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->Gutenberg==0.8.2) (2.0.1)
# Building wheels for collected packages: Gutenberg
#   Building wheel for Gutenberg (setup.py) ... done
#   Created wheel for Gutenberg: filename=Gutenberg-0.8.2-py3-none-any.whl size=25412 sha256=0d6f0d4c815a55fa92ea5f1499bd38b4a9d172317a856fb68ddc1994928a1f1e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8ke_nun_/wheels/75/e3/d8/457855a78992fe264f4d6a78e20081e1f06b1d05f5c6903ed3
# Successfully built Gutenberg
# Installing collected packages: Gutenberg
#   Attempting uninstall: Gutenberg
#     Found existing installation: Gutenberg 0.8.2
#     Uninstalling Gutenberg-0.8.2:
#       Successfully uninstalled Gutenberg-0.8.2
# Successfully installed Gutenberg-0.8.2

# %% [markdown]
# ### Load Metadata/Cache book metadata

# %%
# Get book text by using book id
from gutenberg.acquire import load_etext
# Remove "The Project Gutenberg eBook" header text
from gutenberg.cleanup import strip_headers

# %%
from gutenberg.query import list_supported_metadatas
print(list_supported_metadatas()) # prints (u'author', u'formaturi', u'language', ...)
# Out:
# ('author', 'formaturi', 'language', 'rights', 'subject', 'title')

# %%
from gutenberg.acquire import get_metadata_cache
cache = get_metadata_cache()
cache.populate()
# Out:
# WARNING:rdflib.term:https://www.gutenberg.org/files/35830/maps/Copy of cc-map.gif does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-wav/Joy - Janis Ian.wav does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-mp3/Billie's Bones - Janis Ian - BB.mp3 does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-aac/Jackie Skates - Janis Ian - FITNB.aac does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-wav/Forever Young - Janis Ian - BB.wav does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-wav/My Tennessee Hills - Janis Ian.wav does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-mp3/Jackie Skates - Janis Ian - FITNB.mp3 does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-ogg/Days Like These - Janis Ian.ogg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-wma/Standing In the Shadows of Love - Janis Ian - FITNB.wma does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-ogg/The Last Train - Janis Ian - FITNB.ogg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-wav/The Great Divide - Janis Ian - FITNB.wav does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-ogg/Folk is the New Black - Janis Ian - FITNB.ogg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-ogg/The Drowing Man - Janis Ian - FITNB.ogg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-ogg/Danger Danger - Janis Ian - FITNB.ogg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-aac/Joy - Janis Ian.aac does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-wma/Stolen Fire - Janis Ian.wma does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-ogg/Joy - Janis Ian.ogg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-mp3/Standing In the Shadows of Love - Janis Ian - FITNB.mp3 does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567-mp3/The Last Train - Janis Ian - FITNB.mp3 does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/36567/36567
not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802684.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/Iran.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802683.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802700.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802689.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802696.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802685.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802690.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802686.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802693.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802687.jpg does not look like a valid URI, trying to serialize this will break.
# WARNING:rdflib.term:https://www.gutenberg.org/files/3672/reference/JPEG versions/802701.jpg does not look like a valid URI, trying to serialize this will break.

# %% [markdown]
# ### Create dataset with text data/inputs and author labels/outputs

# %%
from pandas.core.dtypes.common import is_datetime64tz_dtype
from gutenberg.query import get_etexts
from gutenberg.query import get_metadata

sample_txt_ids = [
                  1513, 1524, 1533, 1112, 1514, 1531, 1522, 1532, 1515, 1519, # William Shakespeare
                  1342, 158, 161, 105, 121, 141, 946, 42078, 1212, # Jane Austen
                  98, 1400, 730, 766, 1023, 580, 883, 700, 967, 1289, 807, 25852, # Charles Dickens
                  205, 71, 1022, 34392, 42553, 4232, 34990, 42500, 9846, 60951, # Henry David Thoreau
                  140, 38117, 63293, 63693, 7522, 5421, 5776, 65576, 3304, 5774, # Upton Sinclair
                  64317, 805, 6695, 4368, 60962, # F. Scott Fitzgerald
                  1661, 2852, 244, 2097, 834, 139, 108, 903, 537, 2347, # Arthur Conan Doyle
                  16, 26654, 20914, 1376, 18934, 4021, 3490, 9617, 342, 6965, # J.M Barrie
                  76, 74, 86, 1837, 3176, 245, 3177, 3189, 3174, 119, # Mark Twain
                  84, 18247, 15238, 56665, 6447, 66749, 66545, 64329, 63337, 64555, # Mary Shelley
                  1497, 1656, 1672, 1750, 1600, 1636, 1726, 1658, 1642, 1572, # Plato
                  2148, 2147, 932, 1064, 32037, 1063, 2151, 2149, 17192, 2150, # Edgar Allan Poe
                  55, 520, 54, 22566, 4357, 33361, 419, 41667, 26624, 52176, # Lyman Frank Baum
                  408, 15210, 62582, 15265, 66398, 17700, 15359, 31254, 62799, 5685, # W.E.B. Du Bois
                  204, 1695, 1717, 1719, 130, 67639, 8092, 470, 223, 65688, # Gilbert Keith Chesterton
                  45, 47, 51, 544, 3796, 5343, 61236, 1354, 5342, 316, # Lucy Maude Montgomery
                  34568, 35601, 34550, 34737, 34582, 35013, 35070, 35157, 35097, 35128, # Thomas Tapper
                  25344, 13707, 77, 2081, 976, 32242, 513, 9243, 1916, 512, # Nathaniel Hawthorne
                  219, 220, 5658, 974, 2021, 17731, 1142, 1202, 495, 2480, # Joseph Conrad
                  863, 61262, 58866, 1155, 61168, 67173, 67160, 65238, 66446 # Agatha Christie
                  ]

def text_extractor(txt_id):
  txt = strip_headers(load_etext(etextno=txt_id))
  #return nltk.word_tokenize(txt)
  return txt

def metadata_getter(feat_name, txt_id):
  return str(list(get_metadata(feat_name, txt_id)))[2:-2]

data = {"text": [],
        "author" :[],
        "etxt_id" : [],
        "title" : [], 
        "subject" : []
        }

for id in sample_txt_ids:
  # Keep only etexts with singular attributed author
  assert len(get_metadata("author", id)) == 1, f"Author issue! Check etextno: {id}"
  data['text'].append(text_extractor(id))
  data['author'].append(metadata_getter('author', id))
  data["etxt_id"].append(id)
  data['title'].append(metadata_getter('title', id))
  data['subject'].append(metadata_getter('subject', id))

df = pd.DataFrame(data)

# %%
author_vals = {k:v for k, v in list(zip(np.arange(0, len(pd.factorize(df.author)[1])), pd.factorize(df.author)[1]), )}
df["author_label"] = pd.factorize(df.author)[0]
df.head(50)
# Out:
#                                                  text                author  \
# 0   \n\n\n\nTHE TRAGEDY OF ROMEO AND JULIET\n\n\n\...  Shakespeare, William
# 1   \n\n\n\nTHE TRAGEDY OF HAMLET, PRINCE OF DENMA...  Shakespeare, William
# 2   \ncover \n\n\n\nMACBETH\n\nby William Shakespe...  Shakespeare, William
# 3   \n\n\n\n\n\n\n\n\n\n\n\n\n*Project Gutenberg i...  Shakespeare, William
# 4   \ncover \n\n\n\n\nA MIDSUMMER NIGHT’S DREAM\n\...  Shakespeare, William
# 5   \ncover \n\n\n\nOTHELLO, THE MOOR OF VENICE\n\...  Shakespeare, William
# 6   \n\n\n\nTHE TRAGEDY OF JULIUS CAESAR\n\n\nby W...  Shakespeare, William
# 7   \n\n\n\nTHE TRAGEDY OF KING LEAR\n\nby William...  Shakespeare, William
# 8   \ncover\n\n\n\n\nTHE MERCHANT OF VENICE\n\n\nb...  Shakespeare, William
# 9   \n\n\n\nMUCH ADO ABOUT NOTHING\n\nby William S...  Shakespeare, William
# 10  \n\n\n\nTHERE IS AN ILLUSTRATED EDITION OF THI...          Austen, Jane
# 11  \n\n\n\nEmma\n\nby Jane Austen\n\n\nContents\n...          Austen, Jane
# 12  \n[Illustration]\n\n\n\n\nSense and Sensibilit...          Austen, Jane
# 13  by Al Haines.\n\n\n\n\n\n\n\n\n\n\nPersuasion\...          Austen, Jane
# 14  \n\n\n\nNorthanger Abbey\n\n\nby Jane Austen\n...          Austen, Jane
# 15  \n\n\n\nMANSFIELD PARK\n\n(1814)\n\nBy Jane Au...          Austen, Jane
# 16  \n\n\n\n\nLADY SUSAN\n\nby Jane Austen\n\n\n\n...          Austen, Jane
# 17  \n\n\n\n\n\n\n[Transcriber's Note: letters tha...          Austen, Jane
# 18  \n\n\n\n\n\n\n\n\n\nLOVE AND FREINDSHIP AND OT...          Austen, Jane
# 19  \n\n\n\nA TALE OF TWO CITIES\n\nA STORY OF THE...      Dickens, Charles
# 20  \n[Illustration]\n\n\n\n\nGreat Expectations\n...      Dickens, Charles
# 21  \n\n\n\nOliver Twist\n\nOR\nTHE PARISH BOY’S P...      Dickens, Charles
# 22  \n\n\n\n\nDAVID COPPERFIELD\n\n\nBy Charles Di...      Dickens, Charles
# 23  and revised by Thomas Berger and Joseph E. Loe...      Dickens, Charles
# 24  \n\n\nTHE PICKWICK PAPERS\n\n\nBy Charles Dick...      Dickens, Charles
# 25  \n\n\n\n\nOUR MUTUAL FRIEND\n\nCharles Dickens...      Dickens, Charles
# 26  \n\n\n\nThe Old Curiosity Shop\n\nBy Charles D...      Dickens, Charles
# 27  \n\n\n\n\nTHE LIFE AND ADVENTURES OF NICHOLAS ...      Dickens, Charles
# 28  \n\nTranscribed from the 1894 Chapman and Hall...      Dickens, Charles
# 29  \n\nTranscribed from the 1905 Chapman and Hall...      Dickens, Charles
# 30  \n\n\n\n\n\nFor the reader: Things that were h...      Dickens, Charles
# 31  \n\n\n\nWALDEN\n\n\n\n\nand\n\n\n\nON THE DUTY...  Thoreau, Henry David
# 32  \n\n\n\n On the Duty of Civil Disobedience\n\n...  Thoreau, Henry David
# 33  \n\n\n\nWALKING\n\nby Henry David Thoreau\n\n\...  Thoreau, Henry David
# 34  \n[Illustration]\n\n[Illustration]\n\n\n\n\nCa...  Thoreau, Henry David
# 35  \n\nTranscriber's note:\n\n      Text enclosed...  Thoreau, Henry David
# 36  \n[Illustration]\n\n\n\n\nA Week on the Concor...  Thoreau, Henry David
# 37  \n\n\n\nCANOEING\nIN THE\nWILDERNESS\n\nHENRY ...  Thoreau, Henry David
# 38  \n\n\n\nThe Writings of Henry David Thoreau\n\...  Thoreau, Henry David
# 39  \n[Illustration]\n\n\n\n\nExcursions\n\nby Hen...  Thoreau, Henry David
# 40  \n\n\n\n\n\n\n\n\n\n\n\n\nThe Service\n\nby He...  Thoreau, Henry David
# 41  \n[Illustration]\n\n\n\n\nThe Jungle\n\nby Upt...       Sinclair, Upton
# 42  produced from images available at The Internet...       Sinclair, Upton
# 43  Proofreading Team (http://www.pgdp.net) from p...       Sinclair, Upton
# 44  \n\n\n\n                              MENTAL R...       Sinclair, Upton
# 45  \n\n\n\n\n\n\n\nKING COAL\n\n_A NOVEL_\n\nBy U...       Sinclair, Upton
# 46  \n[illustration]\n\n\n\n\nThe Metropolis\n\nby...       Sinclair, Upton
# 47  \n\n\n\n\n\n100%: THE STORY OF A PATRIOT\n\nBy...       Sinclair, Upton
# 48  \n--------------------------------------------...       Sinclair, Upton
# 49  \n\n\n\n\nTHE MACHINE\n\nBy Upton Sinclair\n\n...       Sinclair, Upton
#
#     etxt_id                                              title  \
# 0      1513                                   Romeo and Juliet
# 1      1524                          Hamlet, Prince of Denmark
# 2      1533                                            Macbeth
# 3      1112                    The Tragedy of Romeo and Juliet
# 4      1514                          A Midsummer Night's Dream
# 5      1531                        Othello, the Moor of Venice
# 6      1522                                      Julius Caesar
# 7      1532                           The Tragedy of King Lear
# 8      1515                             The Merchant of Venice
# 9      1519                             Much Ado about Nothing
# 10     1342                                Pride and Prejudice
# 11      158                                               Emma
# 12      161                              Sense and Sensibility
# 13      105                                         Persuasion
# 14      121                                   Northanger Abbey
# 15      141                                     Mansfield Park
# 16      946                                         Lady Susan
# 17    42078  The Letters of Jane Austen\r\nSelected from th...
# 18     1212                          Love and Freindship [sic]
# 19       98                               A Tale of Two Cities
# 20     1400                                 Great Expectations
# 21      730                                       Oliver Twist
# 22      766                                  David Copperfield
# 23     1023                                        Bleak House
# 24      580                                The Pickwick Papers
# 25      883                                  Our Mutual Friend
# 26      700                             The Old Curiosity Shop
# 27      967                                  Nicholas Nickleby
# 28     1289                                Three Ghost Stories
# 29      807  Hunted Down: The Detective Stories of Charles ...
# 30    25852  The Letters of Charles Dickens. Vol. 1, 1833-1856
# 31      205      Walden, and On The Duty Of Civil Disobedience
# 32       71                  On the Duty of Civil Disobedience
# 33     1022                                            Walking
# 34    34392                                           Cape Cod
# 35    42553  Excursions, and Poems\r\nThe Writings of Henry...
# 36     4232         A Week on the Concord and Merrimack Rivers
# 37    34990                         Canoeing in the wilderness
# 38    42500  The Maine Woods\r\nThe Writings of Henry David...
# 39     9846                                         Excursions
# 40    60951                                        The Service
# 41      140                                         The Jungle
# 42    38117                                   The Book of Life
# 43    63293                                   The Fasting Cure
# 44    63693                                       Mental Radio
# 45     7522                                King Coal : a Novel
# 46     5421                                     The Metropolis
# 47     5776                       100%: the Story of a Patriot
# 48    65576      The Goslings: A Study of the American Schools
# 49     3304                                        The Machine
#
#                                               subject  author_label
# 0   Youth -- Drama', 'Juliet (Fictitious character...             0
# 1   Tragedies', 'Denmark -- Drama', 'Fathers -- De...             0
# 2   Regicides -- Drama', 'Tragedies', 'Macbeth, Ki...             0
# 3   Juliet (Fictitious character) -- Drama', 'Yout...             0
# 4   Athens (Greece) -- Drama', 'Comedies', 'Fairy ...             0
# 5   Tragedies', 'Venice (Italy) -- Drama', 'Muslim...             0
# 6   Tragedies', 'Caesar, Julius -- Assassination -...             0
# 7   Lear, King (Legendary character) -- Drama', 'T...             0
# 8   Comedies', 'Moneylenders -- Drama', 'Venice (I...             0
# 9   Messina (Italy) -- Drama', 'Comedies', 'Reject...             0
# 10  Love stories', 'Sisters -- Fiction', 'Social c...             1
# 11  Love stories', 'Bildungsromans', 'England -- F...             1
# 12  Love stories', 'Sisters -- Fiction', 'Regency ...             1
# 13  Love stories', 'Rejection (Psychology) -- Fict...             1
# 14  Love stories', 'Books and reading -- Fiction',...             1
# 15  Love stories', 'Adoptees -- Fiction', 'England...             1
# 16  Epistolary fiction', 'Widows -- Fiction', 'Eng...             1
# 17  Austen, Cassandra, 1773-1845', 'Novelists, Eng...             1
# 18  Epistolary fiction', 'Essays', 'England -- Soc...             1
# 19  Lookalikes -- Fiction', 'Paris (France) -- His...             2
# 20  Bildungsromans', 'Orphans -- Fiction', 'Young ...             2
# 21  Bildungsromans', 'Orphans -- Fiction', 'London...             2
# 22  Child labor -- Fiction', 'Bildungsromans', 'Au...             2
# 23  Bildungsromans', 'Domestic fiction', 'London (...             2
# 24  Male friendship -- Fiction', 'England -- Ficti...             2
# 25  Love stories', 'Poor families -- Fiction', 'So...             2
# 26  Didactic fiction', 'Antique dealers -- Fiction...             2
# 27  Picaresque literature', 'Poor families -- Fict...             2
# 28             Ghost stories', 'English fiction', 'PR             2
# 29       PR', 'Detective and mystery stories, English             2
# 30  Novelists, English -- 19th century -- Correspo...             2
# 31  Wilderness areas -- Massachusetts -- Walden Wo...             3
# 32  HM', 'Government, Resistance to', 'PS', 'Civil...             3
# 33                  Walking', 'Essays', 'Nature', 'PS             3
# 34  Cape Cod (Mass.) -- Description and travel', '...             3
# 35  Greek poetry -- Translations into English', 'N...             3
# 36  Thoreau, Henry David, 1817-1862 -- Travel -- M...             3
# 37  Maine -- Description and travel', 'Canoes and ...             3
# 38  F001', 'Maine -- Description and travel', 'Pis...             3
# 39                                       Essays', 'PS             3
# 40              American essays -- 19th century', 'PS             3
# 41  Working class -- Fiction', 'Chicago (Ill.) -- ...             4
# 42                      Love', 'BD', 'Life', 'Hygiene             4
# 43                                      RM', 'Fasting             4
# 44  Sinclair, Mary Craig, 1883-1961', 'Telepathy -...             4
# 45  Coal miners -- Fiction', 'PS', 'Coal mines and...             4
# 46  Socialites -- Fiction', 'Upper class -- Fictio...             4
# 47  Communists -- United States -- Fiction', 'Agen...             4
# 48                   LA', 'Education -- United States             4
# 49  Political corruption -- Drama', 'Socialists --...             4

# %% [markdown]
# ### Export dataset to designated Drive folder.

# %% [markdown]
# Set the working directory for this notebook for ease of access to files.
#
# The command lines below assumes that the `W266 Term Project` folder is a shortcut in your Google Drive main/homepage (My Drive)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pwd
# Out:
# /content/Gutenberg

# %%
# %cd ../gdrive/MyDrive/'W266 Term Project'
# Out:
# /content/gdrive/.shortcut-targets-by-id/1_FXrZ5ThkxncTxzIULW-MqLHa5Qo-qn6/W266 Term Project

# %%
# Export generated data to the designated folder
data = df.to_csv('data.csv')

# %%
author_vals
# Out:
# {0: 'Shakespeare, William',
#  1: 'Austen, Jane',
#  2: 'Dickens, Charles',
#  3: 'Thoreau, Henry David',
#  4: 'Sinclair, Upton',
#  5: 'Fitzgerald, F. Scott (Francis Scott)',
#  6: 'Doyle, Arthur Conan',
#  7: 'Barrie, J. M. (James Matthew)',
#  8: 'Twain, Mark',
#  9: 'Shelley, Mary Wollstonecraft',
#  10: 'Plato',
#  11: 'Poe, Edgar Allan',
#  12: 'Baum, L. Frank (Lyman Frank)',
#  13: 'Du Bois, W. E. B. (William Edward Burghardt)',
#  14: 'Chesterton, G. K. (Gilbert Keith)',
#  15: 'Montgomery, L. M. (Lucy Maud)',
#  16: 'Tapper, Thomas',
#  17: 'Hawthorne, Nathaniel',
#  18: 'Conrad, Joseph',
#  19: 'Christie, Agatha'}

# %%
# Export `author_vals` dictionary for loading into pipeline/model evaluation
# Src: https://pythonspot.com/save-a-dictionary-to-a-file/
import pickle

# create a binary pickle file 
f = open("id2auth.pkl","wb")

# write the python object (dict) to pickle file
pickle.dump(author_vals,f)

# close file
f.close()

# %% [markdown]
# ### Load exported data as Pandas DataFrame
# As a check to see that the code worked and we get text that is only the book text (no Project Gutenberg headers).

# %%
import_exported_data = pd.read_csv('data.csv')
import_exported_data.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  \n\n\n\nTHE TRAGEDY OF ROMEO AND JULIET\n\n\n\...
# 1           1  \n\n\n\nTHE TRAGEDY OF HAMLET, PRINCE OF DENMA...
# 2           2  \ncover \n\n\n\nMACBETH\n\nby William Shakespe...
# 3           3  \n\n\n\n\n\n\n\n\n\n\n\n\n*Project Gutenberg i...
# 4           4  \ncover \n\n\n\n\nA MIDSUMMER NIGHT’S DREAM\n\...
#
#                  author  etxt_id                            title  \
# 0  Shakespeare, William     1513                 Romeo and Juliet
# 1  Shakespeare, William     1524        Hamlet, Prince of Denmark
# 2  Shakespeare, William     1533                          Macbeth
# 3  Shakespeare, William     1112  The Tragedy of Romeo and Juliet
# 4  Shakespeare, William     1514        A Midsummer Night's Dream
#
#                                              subject  author_label
# 0  Youth -- Drama', 'Juliet (Fictitious character...             0
# 1  Tragedies', 'Denmark -- Drama', 'Fathers -- De...             0
# 2  Regicides -- Drama', 'Tragedies', 'Macbeth, Ki...             0
# 3  Juliet (Fictitious character) -- Drama', 'Yout...             0
# 4  Athens (Greece) -- Drama', 'Comedies', 'Fairy ...             0

# %%
import_exported_data[['text', 'author_label']]
# Out:
#                                                   text  author_label
# 0    \n\n\n\nTHE TRAGEDY OF ROMEO AND JULIET\n\n\n\...             0
# 1    \n\n\n\nTHE TRAGEDY OF HAMLET, PRINCE OF DENMA...             0
# 2    \ncover \n\n\n\nMACBETH\n\nby William Shakespe...             0
# 3    \n\n\n\n\n\n\n\n\n\n\n\n\n*Project Gutenberg i...             0
# 4    \ncover \n\n\n\n\nA MIDSUMMER NIGHT’S DREAM\n\...             0
# ..                                                 ...           ...
# 190  \n\n\n\n  THE MAN IN THE BROWN SUIT\n\n\n\n\n ...            19
# 191  \n\n                           The Missing Wil...            19
# 192  \n\n                       The Hunter’s Lodge ...            19
# 193  \n    AGATHA\n    CHRISTIE\n\n\n\n\n    The Se...            19
# 194  AFFAIR ***\n\n\n[Illustration]\n\n            ...            19
#
# [195 rows x 2 columns]

# %% [markdown]
# Load our `author_vals` dictionary.

# %%
# Check to see our original author_vals dictionary is the same as our pickled/loaded dict
author_vals2 = pickle.load(open("id2auth.pkl", 'rb'))
author_vals == author_vals2
# Out:
# True

# %% [markdown]
# #### Notes/Misc Data Consistency Checks

# %% [markdown]
# ids 57837, 59813, 10947, 15041 don't have authors!
#
# After investingating each id, these books are not actually by a singular author but instead are anthologies made up of many authors. So no authors are listed in the Gutenberg metadata.:
#
# ```
# 	Unnamed: 0	text	                    author	book_ids
# 35	35	      book was produced from...	4	      57837
# 37	37	      \n\n\n\nThe Footpath W...	4	      59813
# 83	83	      \n\n\n\nTHE BEST AMERI...	4		  10947
# 110	110	    \n\n\n\nTHE BEST AMERI...	4		  10947
# 128	128	    \n\n\n\n\n\n[Illustrat...	4		  15041
# ```
#
# I've removed these exact ids and replaced them with non anthologies. I've also added a line of code to skip texts where the 'author' in `list_supported_metadatas()`/('author', 'formaturi', 'language', 'rights', 'subject', 'title') must only have one author (eliminating possibilities of multiple authors (in the case of co-authors) or no authors (in the case of anthology books).

# %%
# Check for duplicated books
# Some books have multiple etext ids due to different book editions/versions so the titles are same but the id is different
import_exported_data[import_exported_data['title'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, text, author, etxt_id, title, subject, author_label]
# Index: []

# %%
# Check for duplicated ids
import_exported_data[import_exported_data['etxt_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, text, author, etxt_id, title, subject, author_label]
# Index: []

# %%
# Check that every row is unique
assert len(import_exported_data) == len(set(import_exported_data['etxt_id']))
# Check that every title is unique (we've removed all books with multple editions)
assert len(set(import_exported_data['etxt_id'])) == len(set(import_exported_data['title']))

# %%
# Check that there are no extra or missing authors
assert len(set(import_exported_data['author'])) == len(author_vals)
# Out:
# True
